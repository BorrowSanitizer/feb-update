# %%
# Filtering Miri's Test Suite
import pandas as pd
miri = pd.read_csv("miri.csv")
f"We ran {miri['src_file'].nunique()} of Miri's integration tests"
# Out:
# 'Miri has 860 integration tests, excluding those with dependencies.'

# %%
miri_dist = miri.groupby(['category']).size().reset_index(name='num_tests')
